# %% [markdown]
# <a href="https://colab.research.google.com/github/rautaditya2606/ACME-Insurance-Premium-Predictor/blob/main/NYC_Taxi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets --quiet
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import matplotlib
# %matplotlib inline
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder
import opendatasets as od
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor, plot_tree, export_text
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
import random

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
database_url = 'https://www.kaggle.com/c/new-york-city-taxi-fare-prediction'
od.download(database_url)
# Out:
# Skipping, found downloaded files in "./new-york-city-taxi-fare-prediction" (use force=True to force download)

# %%
data_dir = '/content/new-york-city-taxi-fare-prediction/'

# %%
# !head {data_dir + '/train.csv'}
# Out:
# key,fare_amount,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count
# 2009-06-15 17:26:21.0000001,4.5,2009-06-15 17:26:21 UTC,-73.844311,40.721319,-73.84161,40.712278,1
# 2010-01-05 16:52:16.0000002,16.9,2010-01-05 16:52:16 UTC,-74.016048,40.711303,-73.979268,40.782004,1
# 2011-08-18 00:35:00.00000049,5.7,2011-08-18 00:35:00 UTC,-73.982738,40.76127,-73.991242,40.750562,2
# 2012-04-21 04:30:42.0000001,7.7,2012-04-21 04:30:42 UTC,-73.98713,40.733143,-73.991567,40.758092,1
# 2010-03-09 07:51:00.000000135,5.3,2010-03-09 07:51:00 UTC,-73.968095,40.768008,-73.956655,40.783762,1
# 2011-01-06 09:50:45.0000002,12.1,2011-01-06 09:50:45 UTC,-74.000964,40.73163,-73.972892,40.758233,1
# 2012-11-20 20:35:00.0000001,7.5,2012-11-20 20:35:00 UTC,-73.980002,40.751662,-73.973802,40.764842,1
# 2012-01-04 17:22:00.00000081,16.5,2012-01-04 17:22:00 UTC,-73.9513,40.774138,-73.990095,40.751048,1
# 2012-12-03 13:10:00.000000125,9,2012-12-03 13:10:00 UTC,-74.006462,40.726713,-73.993078,40.731628,1

# %%
selected_cols = 'fare_amount,pickup_datetime,pickup_longitude,pickup_latitude,dropoff_longitude,dropoff_latitude,passenger_count'.split(',')

# %%
selected_cols
dtypes = {
 'fare_amount': 'float32',
 'pickup_longitude':'float32',
 'pickup_latitude':'float32',
 'dropoff_longitude':'float32',
 'dropoff_latitude':'float32',
 'passenger_count': 'uint8'
}

# %%
def skip_rows(row_idx):
    if row_idx == 0:
        return False
    return random.random() > 0.01
df = pd.read_csv(
    data_dir + '/train.csv',
    usecols=selected_cols,
    dtype=dtypes,
    parse_dates=['pickup_datetime'],
    skiprows=skip_rows
)

# %%
df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               5.7 2010-11-16 19:40:00+00:00        -74.000549
# 1               5.0 2015-02-01 17:24:59+00:00        -73.983711
# 2               5.5 2013-09-25 14:47:00+00:00        -74.003639
# 3               9.7 2012-03-29 18:39:00+00:00        -73.980110
# 4               7.3 2011-12-31 21:05:00+00:00        -73.988548
# ...             ...                       ...               ...
# 553688          7.7 2009-01-19 11:48:47+00:00        -73.995087
# 553689          6.0 2013-02-24 21:25:24+00:00        -73.993835
# 553690          4.5 2009-06-09 10:24:59+00:00        -73.983200
# 553691          7.0 2015-05-03 11:05:29+00:00        -73.960236
# 553692          9.3 2012-02-10 11:07:00+00:00        -73.976784
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.727493         -74.005035         40.719124                1
# 1             40.749619         -73.992615         40.742867                1
# 2             40.747478         -73.999893         40.740650                1
# 3             40.751820         -73.950905         40.775948                1
# 4             40.748764         -74.000816         40.718128                1
# ...                 ...                ...               ...              ...
# 553688        40.739735         -73.974739         40.755974                1
# 553689        40.729855         -73.993988         40.720776                1
# 553690        40.734810         -73.991753         40.726433                1
# 553691        40.758030         -73.981026         40.763073                1
# 553692        40.748306         -73.946960         40.779911                1
#
# [553693 rows x 7 columns]

# %%
test_df = pd.read_csv(data_dir + '/test.csv', parse_dates=['pickup_datetime'])

# %%
test_df
# Out:
#                               key           pickup_datetime  pickup_longitude  \
# 0     2015-01-27 13:08:24.0000002 2015-01-27 13:08:24+00:00        -73.973320
# 1     2015-01-27 13:08:24.0000003 2015-01-27 13:08:24+00:00        -73.986862
# 2     2011-10-08 11:53:44.0000002 2011-10-08 11:53:44+00:00        -73.982524
# 3     2012-12-01 21:12:12.0000002 2012-12-01 21:12:12+00:00        -73.981160
# 4     2012-12-01 21:12:12.0000003 2012-12-01 21:12:12+00:00        -73.966046
# ...                           ...                       ...               ...
# 9909  2015-05-10 12:37:51.0000002 2015-05-10 12:37:51+00:00        -73.968124
# 9910  2015-01-12 17:05:51.0000001 2015-01-12 17:05:51+00:00        -73.945511
# 9911  2015-04-19 20:44:15.0000001 2015-04-19 20:44:15+00:00        -73.991600
# 9912  2015-01-31 01:05:19.0000005 2015-01-31 01:05:19+00:00        -73.985573
# 9913  2015-01-18 14:06:23.0000006 2015-01-18 14:06:23+00:00        -73.988022
#
#       pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0           40.763805         -73.981430         40.743835                1
# 1           40.719383         -73.998886         40.739201                1
# 2           40.751260         -73.979654         40.746139                1
# 3           40.767807         -73.990448         40.751635                1
# 4           40.789775         -73.988565         40.744427                1
# ...               ...                ...               ...              ...
# 9909        40.796997         -73.955643         40.780388                6
# 9910        40.803600         -73.960213         40.776371                6
# 9911        40.726608         -73.789742         40.647011                6
# 9912        40.735432         -73.939178         40.801731                6
# 9913        40.754070         -74.000282         40.759220                6
#
# [9914 rows x 7 columns]

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  553693.000000     553693.000000    553693.000000      553688.000000
# mean       11.339559        -72.517670        39.929035         -72.522392
# std         9.767504         13.446193         8.455087          12.228749
# min       -57.330002      -3337.128174     -2485.697266       -2256.421143
# 25%         6.000000        -73.992065        40.734928         -73.991379
# 50%         8.500000        -73.981758        40.752689         -73.980133
# 75%        12.500000        -73.967102        40.767105         -73.963737
# max       465.000000       2553.027588      1703.092773        2832.669189
#
#        dropoff_latitude  passenger_count
# count     553688.000000    553693.000000
# mean          39.909504         1.687074
# std            9.802295         1.310125
# min        -3472.655518         0.000000
# 25%           40.734081         1.000000
# 50%           40.753170         1.000000
# 75%           40.768089         2.000000
# max         2023.273804        34.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553693 entries, 0 to 553692
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        553693 non-null  float32
#  1   pickup_datetime    553693 non-null  datetime64[ns, UTC]
#  2   pickup_longitude   553693 non-null  float32
#  3   pickup_latitude    553693 non-null  float32
#  4   dropoff_longitude  553688 non-null  float32
#  5   dropoff_latitude   553688 non-null  float32
#  6   passenger_count    553693 non-null  uint8
# dtypes: datetime64[ns, UTC](1), float32(5), uint8(1)
# memory usage: 15.3 MB

# %%
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_df.shape, val_df.shape
# Out:
# ((442954, 7), (110739, 7))

# %%
train_df = train_df.dropna()
val_df = val_df.dropna()

# %%
list(train_df.columns)
# Out:
# ['fare_amount',
#  'pickup_datetime',
#  'pickup_longitude',
#  'pickup_latitude',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'passenger_count']

# %%
input_cols = [
 'pickup_longitude',
 'pickup_latitude',
 'dropoff_longitude',
 'dropoff_latitude',
 'passenger_count']
target_cols = 'fare_amount'

# %%
train_inputs = train_df[input_cols]
train_targets = train_df[target_cols]
val_inputs = val_df[input_cols]
val_targets = val_df[target_cols]

# %%
def add_dateparts(df, col):
  df[col+'_year'] = df[col].dt.year
  df[col+'_month'] = df[col].dt.month
  df[col+'_day'] = df[col].dt.day
  df[col+'_weekday'] = df[col].dt.weekday
  df[col+'_hour'] = df[col].dt.hour

# %%
add_dateparts(train_df, 'pickup_datetime')
add_dateparts(val_df, 'pickup_datetime')
add_dateparts(test_df, 'pickup_datetime')

# %%
train_df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 121432          8.1 2010-09-08 09:46:06+00:00        -73.874496
# 498657         11.3 2011-11-14 06:44:19+00:00        -73.926598
# 286115         16.5 2013-02-06 21:16:30+00:00        -74.009521
# 17908          11.0 2014-06-16 20:32:37+00:00          0.000000
# 18842          10.1 2012-06-30 19:28:00+00:00        -73.955223
# ...             ...                       ...               ...
# 110268          6.1 2010-06-28 11:30:00+00:00        -73.789490
# 259178          7.3 2011-03-22 09:00:23+00:00        -73.984894
# 365838          7.0 2013-10-19 18:24:13+00:00        -73.977051
# 131932          6.5 2009-09-09 23:22:14+00:00        -74.001251
# 121958          4.5 2014-11-22 22:34:16+00:00        -73.981071
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 121432        40.774097         -73.985855         40.741676                1
# 498657        40.765701         -73.958199         40.768700                1
# 286115        40.705925         -73.962799         40.719734                1
# 17908          0.000000           0.000000          0.000000                1
# 18842         40.764717         -73.988647         40.750027                1
# ...                 ...                ...               ...              ...
# 110268        40.655788         -73.789001         40.654480                5
# 259178        40.742836         -73.977356         40.752766                1
# 365838        40.743366         -73.961365         40.758675                1
# 131932        40.737549         -73.992218         40.758480                1
# 121958        40.744537         -73.984856         40.736488                1
#
#         pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 121432                  2010                      9                    8
# 498657                  2011                     11                   14
# 286115                  2013                      2                    6
# 17908                   2014                      6                   16
# 18842                   2012                      6                   30
# ...                      ...                    ...                  ...
# 110268                  2010                      6                   28
# 259178                  2011                      3                   22
# 365838                  2013                     10                   19
# 131932                  2009                      9                    9
# 121958                  2014                     11                   22
#
#         pickup_datetime_weekday  pickup_datetime_hour
# 121432                        2                     9
# 498657                        0                     6
# 286115                        2                    21
# 17908                         0                    20
# 18842                         5                    19
# ...                         ...                   ...
# 110268                        0                    11
# 259178                        1                     9
# 365838                        5                    18
# 131932                        2                    23
# 121958                        5                    22
#
# [442950 rows x 12 columns]

# %%
val_df
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 53296           9.3 2011-05-17 20:39:35+00:00        -73.983658
# 349746          7.7 2011-12-11 21:54:58+00:00        -73.976685
# 125418          6.0 2013-05-15 21:40:00+00:00        -73.975082
# 289289          9.7 2009-05-18 12:07:00+00:00        -73.986732
# 371713         16.0 2014-06-01 12:48:38+00:00        -73.998405
# ...             ...                       ...               ...
# 468086          5.5 2015-02-07 12:18:58+00:00        -73.982216
# 386563          4.1 2010-07-08 14:32:41+00:00        -73.991562
# 487538         10.0 2014-07-16 19:41:00+00:00        -74.006615
# 448442          7.3 2012-01-01 01:52:11+00:00        -73.936394
# 228939          6.0 2013-12-16 12:48:54+00:00        -73.996490
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 53296         40.749035         -73.994003         40.722694                1
# 349746        40.765263         -73.945694         40.773602                1
# 125418        40.750896         -73.985847         40.758083                1
# 289289        40.745678         -74.007828         40.740215                1
# 371713        40.716888         -73.985497         40.737564                1
# ...                 ...                ...               ...              ...
# 468086        40.767849         -73.969048         40.761757                1
# 386563        40.747311         -73.998116         40.745304                1
# 487538        40.731117         -73.981941         40.737461                1
# 448442        40.814602         -73.957809         40.801144                4
# 228939        40.723824         -73.988968         40.736485                1
#
#         pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 53296                   2011                      5                   17
# 349746                  2011                     12                   11
# 125418                  2013                      5                   15
# 289289                  2009                      5                   18
# 371713                  2014                      6                    1
# ...                      ...                    ...                  ...
# 468086                  2015                      2                    7
# 386563                  2010                      7                    8
# 487538                  2014                      7                   16
# 448442                  2012                      1                    1
# 228939                  2013                     12                   16
#
#         pickup_datetime_weekday  pickup_datetime_hour
# 53296                         1                    20
# 349746                        6                    21
# 125418                        2                    21
# 289289                        0                    12
# 371713                        6                    12
# ...                         ...                   ...
# 468086                        5                    12
# 386563                        3                    14
# 487538                        2                    19
# 448442                        6                     1
# 228939                        0                    12
#
# [110738 rows x 12 columns]

# %%
test_df
# Out:
#                               key           pickup_datetime  pickup_longitude  \
# 0     2015-01-27 13:08:24.0000002 2015-01-27 13:08:24+00:00        -73.973320
# 1     2015-01-27 13:08:24.0000003 2015-01-27 13:08:24+00:00        -73.986862
# 2     2011-10-08 11:53:44.0000002 2011-10-08 11:53:44+00:00        -73.982524
# 3     2012-12-01 21:12:12.0000002 2012-12-01 21:12:12+00:00        -73.981160
# 4     2012-12-01 21:12:12.0000003 2012-12-01 21:12:12+00:00        -73.966046
# ...                           ...                       ...               ...
# 9909  2015-05-10 12:37:51.0000002 2015-05-10 12:37:51+00:00        -73.968124
# 9910  2015-01-12 17:05:51.0000001 2015-01-12 17:05:51+00:00        -73.945511
# 9911  2015-04-19 20:44:15.0000001 2015-04-19 20:44:15+00:00        -73.991600
# 9912  2015-01-31 01:05:19.0000005 2015-01-31 01:05:19+00:00        -73.985573
# 9913  2015-01-18 14:06:23.0000006 2015-01-18 14:06:23+00:00        -73.988022
#
#       pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0           40.763805         -73.981430         40.743835                1
# 1           40.719383         -73.998886         40.739201                1
# 2           40.751260         -73.979654         40.746139                1
# 3           40.767807         -73.990448         40.751635                1
# 4           40.789775         -73.988565         40.744427                1
# ...               ...                ...               ...              ...
# 9909        40.796997         -73.955643         40.780388                6
# 9910        40.803600         -73.960213         40.776371                6
# 9911        40.726608         -73.789742         40.647011                6
# 9912        40.735432         -73.939178         40.801731                6
# 9913        40.754070         -74.000282         40.759220                6
#
#       pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 0                     2015                      1                   27
# 1                     2015                      1                   27
# 2                     2011                     10                    8
# 3                     2012                     12                    1
# 4                     2012                     12                    1
# ...                    ...                    ...                  ...
# 9909                  2015                      5                   10
# 9910                  2015                      1                   12
# 9911                  2015                      4                   19
# 9912                  2015                      1                   31
# 9913                  2015                      1                   18
#
#       pickup_datetime_weekday  pickup_datetime_hour
# 0                           1                    13
# 1                           1                    13
# 2                           5                    11
# 3                           5                    21
# 4                           5                    21
# ...                       ...                   ...
# 9909                        6                    12
# 9910                        0                    17
# 9911                        6                    20
# 9912                        5                     1
# 9913                        6                    14
#
# [9914 rows x 12 columns]

# %%
def haversine_vectorized(lat1, lon1, lat2, lon2):
    # Convert degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6371 * c
    return km

def add_trip_dist(df):
    df['trip_distance'] = haversine_vectorized(
        df['pickup_latitude'],
        df['pickup_longitude'],
        df['dropoff_latitude'],
        df['dropoff_longitude']
    )

# %%
add_trip_dist(train_df)
add_trip_dist(val_df)
add_trip_dist(test_df)

# %%
val_df.head(1)
# Out:
#        fare_amount           pickup_datetime  pickup_longitude  \
# 53296          9.3 2011-05-17 20:39:35+00:00        -73.983658
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 53296        40.749035         -73.994003         40.722694                1
#
#        pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 53296                  2011                      5                   17
#
#        pickup_datetime_weekday  pickup_datetime_hour  trip_distance  \
# 53296                        1                    20       3.055787
#
#        jfk_drop_distance  lga_drop_distance  ewr_drop_distance  \
# 53296          24.138298          13.447196          20.096348
#
#        met_drop_distance  wtc_drop_distance
# 53296           3.841302           1.794937

# %%
train_df.head(1)
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 121432          8.1 2010-09-08 09:46:06+00:00        -73.874496
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 121432        40.774097         -73.985855         40.741676                1
#
#         pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 121432                  2010                      9                    8
#
#         pickup_datetime_weekday  pickup_datetime_hour  trip_distance  \
# 121432                        2                     9      10.048539
#
#         jfk_drop_distance  lga_drop_distance  ewr_drop_distance  \
# 121432          23.308048          12.484447          21.037176
#
#         met_drop_distance  wtc_drop_distance
# 121432           2.771911           2.818758

# %%
test_df.head(1)
# Out:
#                            key           pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002 2015-01-27 13:08:24+00:00         -73.97332
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0        40.763805          -73.98143         40.743835                1
#
#    pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 0                  2015                      1                   27
#
#    pickup_datetime_weekday  pickup_datetime_hour  trip_distance  \
# 0                        1                    13        2.32326
#
#    jfk_drop_distance  lga_drop_distance  ewr_drop_distance  met_drop_distance  \
# 0          22.829806          11.988963          21.532282            2.30245
#
#    wtc_drop_distance
# 0           3.307377

# %%
jfk_lonlat = -73.7781, 40.6413
lga_lonlat = -73.8740, 40.7769
ewr_lonlat = -74.1745, 40.6895
met_lonlat = -73.9632, 40.7794
wtc_lonlat = -74.0099, 40.7126

# %%
def add_landmark_dropoff_distance(df, landmark_name, landmark_lonlat):
  lon, lat = landmark_lonlat
  df[landmark_name+'_drop_distance'] = haversine_vectorized(lon, lat, df['dropoff_longitude'], df['dropoff_latitude'])

# %%
def add_landmarks(a_df):
  landmarks = [('jfk', jfk_lonlat), ('lga', lga_lonlat), ('ewr', ewr_lonlat), ('met', met_lonlat), ('wtc', wtc_lonlat)]
  for name, lonlat in landmarks:
    add_landmark_dropoff_distance(a_df, name, lonlat)

# %%
add_landmarks(train_df)
add_landmarks(val_df)
add_landmarks(test_df)

# %%
def remove_outliers(df):
    return df[(df['fare_amount'] >= 1.) &
              (df['fare_amount'] <= 500.) &
              (df['pickup_longitude'] >= -75) &
              (df['pickup_longitude'] <= -72) &
              (df['dropoff_longitude'] >= -75) &
              (df['dropoff_longitude'] <= -72) &
              (df['pickup_latitude'] >= 40) &
              (df['pickup_latitude'] <= 42) &
              (df['dropoff_latitude'] >=40) &
              (df['dropoff_latitude'] <= 42) &
              (df['passenger_count'] >= 1) &
              (df['passenger_count'] <= 6)]

# %%
remove_outliers(train_df)
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 121432          8.1 2010-09-08 09:46:06+00:00        -73.874496
# 498657         11.3 2011-11-14 06:44:19+00:00        -73.926598
# 286115         16.5 2013-02-06 21:16:30+00:00        -74.009521
# 18842          10.1 2012-06-30 19:28:00+00:00        -73.955223
# 475058         10.5 2012-08-24 22:34:06+00:00        -73.985214
# ...             ...                       ...               ...
# 110268          6.1 2010-06-28 11:30:00+00:00        -73.789490
# 259178          7.3 2011-03-22 09:00:23+00:00        -73.984894
# 365838          7.0 2013-10-19 18:24:13+00:00        -73.977051
# 131932          6.5 2009-09-09 23:22:14+00:00        -74.001251
# 121958          4.5 2014-11-22 22:34:16+00:00        -73.981071
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 121432        40.774097         -73.985855         40.741676                1
# 498657        40.765701         -73.958199         40.768700                1
# 286115        40.705925         -73.962799         40.719734                1
# 18842         40.764717         -73.988647         40.750027                1
# 475058        40.719093         -73.988693         40.748459                3
# ...                 ...                ...               ...              ...
# 110268        40.655788         -73.789001         40.654480                5
# 259178        40.742836         -73.977356         40.752766                1
# 365838        40.743366         -73.961365         40.758675                1
# 131932        40.737549         -73.992218         40.758480                1
# 121958        40.744537         -73.984856         40.736488                1
#
#         pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 121432                  2010                      9                    8
# 498657                  2011                     11                   14
# 286115                  2013                      2                    6
# 18842                   2012                      6                   30
# 475058                  2012                      8                   24
# ...                      ...                    ...                  ...
# 110268                  2010                      6                   28
# 259178                  2011                      3                   22
# 365838                  2013                     10                   19
# 131932                  2009                      9                    9
# 121958                  2014                     11                   22
#
#         pickup_datetime_weekday  pickup_datetime_hour  trip_distance  \
# 121432                        2                     9      10.048539
# 498657                        0                     6       2.681721
# 286115                        2                    21       4.226365
# 18842                         5                    19       3.254616
# 475058                        4                    22       3.278507
# ...                         ...                   ...            ...
# 110268                        0                    11       0.151242
# 259178                        1                     9       1.273621
# 365838                        5                    18       2.154794
# 131932                        2                    23       2.448577
# 121958                        5                    22       0.950128
#
#         jfk_drop_distance  lga_drop_distance  ewr_drop_distance  \
# 121432          23.308048          12.484447          21.037176
# 498657          20.409166           9.365546          24.173241
# 286115          20.680344          10.029797          23.558235
# 18842           23.651114          12.774714          20.748545
# 475058          23.649561          12.783232          20.739050
# ...                   ...                ...                ...
# 110268           1.279389          10.183492          42.879410
# 259178          22.422098          11.516483          22.006498
# 365838          20.698509           9.730742          23.793514
# 131932          24.082129          13.157333          20.377920
# 121958          23.177320          12.389002          21.136433
#
#         met_drop_distance  wtc_drop_distance
# 121432           2.771911           2.818758
# 498657           0.646507           6.001367
# 286115           1.833370           5.241961
# 18842            2.969262           2.627185
# 475058           2.989264           2.601744
# ...                   ...                ...
# 110268          19.750950          24.628471
# 259178           1.773463           3.822734
# 365838           0.668580           5.578905
# 131932           3.289533           2.417360
# 121958           2.744365           2.879687
#
# [432251 rows x 18 columns]

# %%
remove_outliers(val_df)
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 53296           9.3 2011-05-17 20:39:35+00:00        -73.983658
# 349746          7.7 2011-12-11 21:54:58+00:00        -73.976685
# 125418          6.0 2013-05-15 21:40:00+00:00        -73.975082
# 289289          9.7 2009-05-18 12:07:00+00:00        -73.986732
# 371713         16.0 2014-06-01 12:48:38+00:00        -73.998405
# ...             ...                       ...               ...
# 468086          5.5 2015-02-07 12:18:58+00:00        -73.982216
# 386563          4.1 2010-07-08 14:32:41+00:00        -73.991562
# 487538         10.0 2014-07-16 19:41:00+00:00        -74.006615
# 448442          7.3 2012-01-01 01:52:11+00:00        -73.936394
# 228939          6.0 2013-12-16 12:48:54+00:00        -73.996490
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 53296         40.749035         -73.994003         40.722694                1
# 349746        40.765263         -73.945694         40.773602                1
# 125418        40.750896         -73.985847         40.758083                1
# 289289        40.745678         -74.007828         40.740215                1
# 371713        40.716888         -73.985497         40.737564                1
# ...                 ...                ...               ...              ...
# 468086        40.767849         -73.969048         40.761757                1
# 386563        40.747311         -73.998116         40.745304                1
# 487538        40.731117         -73.981941         40.737461                1
# 448442        40.814602         -73.957809         40.801144                4
# 228939        40.723824         -73.988968         40.736485                1
#
#         pickup_datetime_year  pickup_datetime_month  pickup_datetime_day  \
# 53296                   2011                      5                   17
# 349746                  2011                     12                   11
# 125418                  2013                      5                   15
# 289289                  2009                      5                   18
# 371713                  2014                      6                    1
# ...                      ...                    ...                  ...
# 468086                  2015                      2                    7
# 386563                  2010                      7                    8
# 487538                  2014                      7                   16
# 448442                  2012                      1                    1
# 228939                  2013                     12                   16
#
#         pickup_datetime_weekday  pickup_datetime_hour  trip_distance  \
# 53296                         1                    20       3.055787
# 349746                        6                    21       2.769913
# 125418                        2                    21       1.208499
# 289289                        0                    12       1.877899
# 371713                        6                    12       2.543322
# ...                         ...                   ...            ...
# 468086                        5                    12       1.299586
# 386563                        3                    14       0.595264
# 487538                        2                    19       2.195705
# 448442                        6                     1       2.342546
# 228939                        0                    12       1.543743
#
#         jfk_drop_distance  lga_drop_distance  ewr_drop_distance  \
# 53296           24.138298          13.447196          20.096348
# 349746          19.078747           7.972175          25.571941
# 125418          23.380011          12.450004          21.081688
# 289289          25.726032          14.923263          18.597994
# 371713          23.252350          12.456769          21.067459
# ...                   ...                ...                ...
# 468086          21.556307          10.579240          22.951385
# 386563          24.674047          13.834753          19.687281
# 487538          22.859591          12.063345          21.462006
# 448442          20.583920           9.348730          24.335146
# 228939          23.630850          12.843976          20.680279
#
#         met_drop_distance  wtc_drop_distance
# 53296            3.841302           1.794937
# 349746           1.955452           7.381263
# 125418           2.601333           3.016427
# 289289           5.105231           0.876855
# 371713           2.791848           2.819468
# ...                   ...                ...
# 468086           0.846314           4.786108
# 386563           4.020246           1.650013
# 487538           2.449008           3.201377
# 448442           0.897925           6.397895
# 228939           3.153083           2.440220
#
# [107942 rows x 18 columns]

# %%
train_df.to_parquet('train.parquet')

# %%
val_df.to_parquet('val.parquet')

# %%
test_df.to_parquet('test.parquet')
